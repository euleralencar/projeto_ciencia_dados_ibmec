# %% [markdown]
# # 📝 Exercício M1.03
#
# O objetivo deste exercício é comparar o desempenho do nosso classificador no
# notebook anterior (aproximadamente 81% de acurácia com `LogisticRegression`)
# com alguns classificadores de referência (baseline) simples. O classificador de
# referência mais simples é aquele que sempre prevê a mesma classe,
# independentemente dos dados de entrada.
#
# * Qual seria o score de um modelo que sempre prevê `' >50K'`?
# * Qual seria o score de um modelo que sempre prevê `' <=50K'`?
# * 81% ou 82% de acurácia é um bom score para este problema?
#
# Use um `DummyClassifier` e faça uma divisão treino-teste para avaliar sua
# acurácia no conjunto de teste. Este
# [link](https://scikit-learn.org/stable/modules/model_evaluation.html#dummy-estimators)
# mostra alguns exemplos de como avaliar o desempenho de generalização desses
# modelos de referência.

# %%
import pandas as pd

adult_census = pd.read_csv("../datasets/adult-census.csv")

# %% [markdown]
# Primeiro dividimos nosso conjunto de dados para ter o alvo separado dos dados
# usados para treinar nosso modelo preditivo.

# %%
target_name = "class"
target = adult_census[target_name]
data = adult_census.drop(columns=target_name)

# %% [markdown]
# Começamos selecionando apenas as colunas numéricas, como visto no notebook
# anterior.

# %%
numerical_columns = ["age", "capital-gain", "capital-loss", "hours-per-week"]

data_numeric = data[numerical_columns]

# %% [markdown]
# Divida os dados e o alvo em um conjunto de treino e um de teste.

# %%
from sklearn.model_selection import train_test_split

# Escreva seu código aqui.

# %% [markdown]
# Use um `DummyClassifier` de forma que o classificador resultante sempre preveja
# a classe `' >50K'`. Qual é o score de acurácia no conjunto de teste? Repita o
# experimento sempre prevendo a classe `' <=50K'`.
#
# Dica: você pode definir o parâmetro `strategy` do `DummyClassifier` para obter
# o comportamento desejado.

# %%
from sklearn.dummy import DummyClassifier

# Escreva seu código aqui.
