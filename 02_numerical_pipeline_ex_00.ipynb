# %% [markdown]
# # 📝 Exercício M1.02
#
# O objetivo deste exercício é ajustar um modelo semelhante ao do notebook
# anterior para se familiarizar com a manipulação de objetos do scikit-learn e,
# em particular, com a API `.fit/.predict/.score`.

# %% [markdown]
# Vamos carregar o conjunto de dados do censo norte-americano apenas com
# variáveis numéricas

# %%
import pandas as pd

adult_census = pd.read_csv("../datasets/adult-census-numeric.csv")
data = adult_census.drop(columns="class")
target = adult_census["class"]

# %% [markdown]
# No notebook anterior, usamos `model = KNeighborsClassifier()`. Todos os modelos
# do scikit-learn podem ser criados sem argumentos. Isso é conveniente porque
# significa que você não precisa entender todos os detalhes de um modelo antes de
# começar a usá-lo.
#
# Um dos parâmetros do `KNeighborsClassifier` é `n_neighbors`. Ele controla o
# número de vizinhos que vamos usar para fazer uma previsão para um novo ponto de
# dado.
#
# Qual é o valor padrão do parâmetro `n_neighbors`?
#
# **Dica**: consulte a documentação no [site do
# scikit-learn](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html)
# ou acesse diretamente a descrição dentro do seu notebook executando a célula a
# seguir. Isso abre um pager apontando para a documentação.

# %%
from sklearn.neighbors import KNeighborsClassifier

KNeighborsClassifier?

# %% [markdown]
# Crie um modelo `KNeighborsClassifier` com `n_neighbors=50`

# %%
# Escreva seu código aqui.

# %% [markdown]
# Ajuste esse modelo aos dados e ao alvo carregados acima

# %%
# Escreva seu código aqui.

# %% [markdown]
# Use seu modelo para fazer previsões nos primeiros 10 pontos de dado dentro dos
# dados. Elas coincidem com os valores reais do alvo?

# %%
# Escreva seu código aqui.

# %% [markdown]
# Calcule a acurácia nos dados de treino.

# %%
# Escreva seu código aqui.

# %% [markdown]
# Agora carregue os dados de teste de
# `"../datasets/adult-census-numeric-test.csv"` e calcule a acurácia nos dados de
# teste.

# %%
# Escreva seu código aqui.
